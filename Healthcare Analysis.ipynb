# %%
#Install necessary libraries
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl
# !pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.3; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.3; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.3; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.3; however, version 23.0.1 is available.
# ...

# %%
#Import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the dataset using pandas and displaying the top 5 rows
data=pd.read_excel('data.xlsx')
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Count the number of rows and columns
data.shape
# Out:
# (303, 14)

# %%
#Print information of dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#Checking the null values
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# There are no null values / missing values in the dataset.

# %%
#Print number of unique values for each variable
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
#Summarize the count, mean, standard deviation, min, and max for numeric variables.
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#Make some columns as categorical
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['sex']=data['sex'].astype('object')
data['cp']=data['cp'].astype('object')
data['fbs']=data['fbs'].astype('object')
data['exang']=data['exang'].astype('object')
data['slope']=data['slope'].astype('object')
data['thal']=data['thal'].astype('object')
data['restecg']=data['restecg'].astype('object')

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps      int64
# chol          int64
# fbs          object
# restecg      object
# thalach       int64
# exang        object
# oldpeak     float64
# slope        object
# ca            int64
# thal         object
# target        int64
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Target variable
data['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
#Replace names in the target
data['target'].replace({1:'Disease',0:'No Disease'})
# Out:
# 0         Disease
# 1         Disease
# 2         Disease
# 3         Disease
# 4         Disease
#           ...
# 298    No Disease
# 299    No Disease
# 300    No Disease
# 301    No Disease
# 302    No Disease
# Name: target, Length: 303, dtype: object

# %%
data['target'].value_counts().plot(kind='bar')
plt.title('Heart Diseases')
plt.show()

# %% [markdown]
# The people with diseases are more than the ones with no disease.

# %%
#Show distribution of Age
sns.histplot(data['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
data['age'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Age statistics
print(min(data['age']))
print(max(data['age']))
print('mean',data['age'].mean())
# Out:
# 29
# 77
# mean 54.366336633663366

# %%
data['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
#Gender Distribution
data['sex'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.show()

# %%
#Chest pain analysis
sns.countplot(x=data['cp'])
plt.title('Chest Pain Analysis')
plt.show()

# %%
#Resting ECG Analysis
sns.countplot(x=data['restecg'])
plt.title('Resting ECG')
plt.show()

# %%
#CA Analysis
sns.countplot(x=data['ca'])
plt.title('CA Analysis')
plt.show()

# %%
#Thal Analysis
sns.countplot(x=data['thal'])
plt.title('thal Analysis')
plt.show()

# %%
#Disease class according to gender
sns.countplot(x='sex',hue='target',data=data)
plt.title('Diseases class according to gender')
# Out:
# Text(0.5, 1.0, 'Diseases class according to gender')

# %%
#Pie chart to show the thal with heart diseases and without it
labels=['zero','normal','fixed defect','reversible defect']
size=[7,18,166,117]
plt.pie(size,labels=labels,colors=['green','pink','blue','orange'],autopct='%1f%%')
plt.show()

# %%
#Sub plot for combine the charts
# pie chart to show the Thal with heart diseases & without it
labels=['zero','normal','fixed defect','reversible defect']
sizes=[2,4,125,24]
plt.pie(sizes,labels=labels,colors=['pink','yellow','green','purple'],autopct='%.1f%%',startangle=140)
plt.title('Thalassemia With Heart diseases')
plt.show()

# pie chart to show the Thal with heart diseases & without it
labels=['zero','normal','fixed defect','reversible defect']
sizes=[2,6,27,83]
plt.title('Thalassemia Without Heart diseases')
plt.pie(sizes,labels=labels,colors=['pink','orange','green','purple'],autopct='%.1f%%',startangle=140)
plt.show()

# %%
# calculate correlation matrix

corr = data.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
sns.heatmap(corr, xticklabels=corr.columns,
            yticklabels=corr.columns, 
            annot=True,
            cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that chest pain (cp) and target(our predictor) have a positive link. This makes sense because having heart disease increases with the severity of chest pain. Chest pain (CP) is an ordinal feature with four possible values. Values 1 through 4 represent different types of angina: typical angina, atypical angina, non-anginal pain, and asymptomatic.
#
# Moreover, we observe a negative connection between our predictor and exercise-induced angina (exang). This makes sense because increased physical activity increases the amount of blood your heart needs, while narrower arteries reduce blood flow.

# %%
df_num=data.select_dtypes(exclude='object')
df_num
# Out:
#      age  trestbps  chol  thalach  oldpeak  ca  target
# 0     63       145   233      150      2.3   0       1
# 1     37       130   250      187      3.5   0       1
# 2     41       130   204      172      1.4   0       1
# 3     56       120   236      178      0.8   0       1
# 4     57       120   354      163      0.6   0       1
# ..   ...       ...   ...      ...      ...  ..     ...
# 298   57       140   241      123      0.2   0       0
# 299   45       110   264      132      1.2   0       0
# 300   68       144   193      141      3.4   2       0
# 301   57       130   131      115      1.2   1       0
# 302   57       130   236      174      0.0   1       0
#
# [303 rows x 7 columns]

# %%
#Define continuous variable and plot
col=['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']
sns.pairplot(data[col+['target']],hue='target')

# %%
#To understand relation btw age and chol based on gender
sns.lmplot(x='age',y='chol',hue='sex',col='target',data=data,markers=['o','x'])

# %%
#ST depression vs Heart Diseases
sns.catplot(x="target", y="oldpeak", hue="slope", kind="bar", data=data);
plt.title('ST depression (induced by exercise relative to rest) vs. Heart Disease',size=25)
plt.xlabel('Heart Disease',size=20)
plt.ylabel('ST depression',size=20)
# Out:
# Text(26.426458333333343, 0.5, 'ST depression')

# %% [markdown]
# When the ventricle is relaxed and repolarized, ST segment depression happens. Heart disease may result from a ST segment trace that is abnormally low or below the baseline. Because low ST Depression puts people at higher risk for heart disease, this lends validity to the picture presented above. However a high ST depression is natural and healthy. The "slope" colour, which has values of 0 for upsloping, 1 for flat, and 2, relates to the peak workout ST segment. Equal distributions of the three slope groups can be seen in both positive and negative heart disease patients.

# %% [markdown]
# # Outlier Detection using Box Plot

# %%
# Box Plot
plt.figure(figsize=(12,8))
sns.boxplot(x= 'target', y= 'thalach',hue="sex", data=data )
plt.title("ST depression Level vs. Heart Disease", fontsize=20)
plt.xlabel("Heart Disease Target",fontsize=16)
plt.ylabel("ST depression induced by exercise relative to rest", fontsize=16)
# Out:
# Text(0, 0.5, 'ST depression induced by exercise relative to rest')

# %% [markdown]
# While negative patients had lower levels of ST depression, positive patients have an increased median for the condition. In addition, there aren't many distinctions between male and female goal outcomes, with the exception of the fact that ST Depression ranges are a little bit larger in men.

# %% [markdown]
# # Outlier detection using Violin Plot

# %%
# Violin plot
plt.figure(figsize=(12,8))
sns.violinplot(x= 'target', y= 'oldpeak',hue="sex", inner='quartile',data= data )
plt.title("Thalach Level vs. Heart Disease",fontsize=20)
plt.xlabel("Heart Disease Target", fontsize=16)
plt.ylabel("Thalach Level", fontsize=16)
# Out:
# Text(0, 0.5, 'Thalach Level')

# %% [markdown]
# We can see that the general distribution and form of the negative vs positive patients are very different. Positive patients have lower median ST depression levels, and a large portion of their data fall between 0 and 2, whereas negative patients' data fall between 1 and 3. Also, there aren't many distinctions between target outcomes for men and women.

# %%
#Visualizing all plots together
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(17,10))
cat_feat = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal','target']
for idx, feature in enumerate(cat_feat):
    ax = axes[int(idx/3), idx%3]
    if feature != 'target':
        sns.countplot(x=feature, hue='target', data=data, ax=ax, palette='Set2')

# %% [markdown]
# # Filtering data by positive & negative Heart Disease patient

# %%
# Filtering data by POSITIVE Heart Disease patient
pos_data = data[data['target']==1]
pos_data.describe()
# Out:
#               age    trestbps        chol     thalach     oldpeak          ca  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean    52.496970  129.303030  242.230303  158.466667    0.583030    0.363636
# std      9.550651   16.169613   53.552872   19.174276    0.780683    0.848894
# min     29.000000   94.000000  126.000000   96.000000    0.000000    0.000000
# 25%     44.000000  120.000000  208.000000  149.000000    0.000000    0.000000
# 50%     52.000000  130.000000  234.000000  161.000000    0.200000    0.000000
# 75%     59.000000  140.000000  267.000000  172.000000    1.000000    0.000000
# max     76.000000  180.000000  564.000000  202.000000    4.200000    4.000000
#
#        target
# count   165.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %%
# Filtering data by NEGATIVE Heart Disease patient
pos_data = data[data['target']==0]
pos_data.describe()
# Out:
#               age    trestbps        chol     thalach     oldpeak          ca  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean    56.601449  134.398551  251.086957  139.101449    1.585507    1.166667
# std      7.962082   18.729944   49.454614   22.598782    1.300340    1.043460
# min     35.000000  100.000000  131.000000   71.000000    0.000000    0.000000
# 25%     52.000000  120.000000  217.250000  125.000000    0.600000    0.000000
# 50%     58.000000  130.000000  249.000000  142.000000    1.400000    1.000000
# 75%     62.000000  144.750000  283.000000  156.000000    2.500000    2.000000
# max     77.000000  200.000000  409.000000  195.000000    6.200000    4.000000
#
#        target
# count   138.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
# Filtering data by NEGATIVE Heart Disease patient
neg_data = data[data['target']==0]
neg_data.describe()
# Out:
#               age    trestbps        chol     thalach     oldpeak          ca  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean    56.601449  134.398551  251.086957  139.101449    1.585507    1.166667
# std      7.962082   18.729944   49.454614   22.598782    1.300340    1.043460
# min     35.000000  100.000000  131.000000   71.000000    0.000000    0.000000
# 25%     52.000000  120.000000  217.250000  125.000000    0.600000    0.000000
# 50%     58.000000  130.000000  249.000000  142.000000    1.400000    1.000000
# 75%     62.000000  144.750000  283.000000  156.000000    2.500000    2.000000
# max     77.000000  200.000000  409.000000  195.000000    6.200000    4.000000
#
#        target
# count   138.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
print("(Positive Patients ST depression): " + str(pos_data['oldpeak'].mean()))
print("(Negative Patients ST depression): " + str(neg_data['oldpeak'].mean()))
# Out:
# (Positive Patients ST depression): 1.5855072463768118
# (Negative Patients ST depression): 1.5855072463768118

# %%
print("(Positive Patients thalach): " + str(pos_data['thalach'].mean()))
print("(Negative Patients thalach): " + str(neg_data['thalach'].mean()))
# Out:
# (Positive Patients thalach): 139.1014492753623
# (Negative Patients thalach): 139.1014492753623

# %% [markdown]
# From comparing positive and negative patients we can see there are large disparities in means for many of our 13 Characteristics. By looking at the specifics, we may see that positive patients have higher average maximal heart rates (thalach). Moreover, compared to rest, positive patients only show roughly a third of the ST depression that exercise causes (oldpeak).

# %% [markdown]
# # Predictive Analysis

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
# Split: the data set into the Training set and Test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 1)

# %%
#Normalize: Standardizing the data will transform the data so that its distribution will have a 
#mean of 0 and a standard deviation of 1

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.27090572,  0.6636838 ,  1.9766492 , ..., -0.66896473,
#         -0.72428597, -2.11701865],
#        [ 1.3708101 , -1.50674161,  0.99843017, ...,  0.96628239,
#          0.27160724, -0.47497213],
#        [ 0.27633288,  0.6636838 ,  0.99843017, ...,  0.96628239,
#          0.27160724,  1.16707438],
#        ...,
#        [-2.78820331,  0.6636838 ,  0.02021114, ...,  0.96628239,
#         -0.72428597, -0.47497213],
#        [-0.38035344,  0.6636838 , -0.95800789, ...,  0.96628239,
#         -0.72428597,  1.16707438],
#        [-0.05201028,  0.6636838 ,  0.99843017, ...,  0.96628239,
#         -0.72428597,  1.16707438]])

# %%
from sklearn.metrics import classification_report 
from sklearn.linear_model import LogisticRegression

model1 = LogisticRegression(random_state=1) # get instance of model
model1.fit(x_train, y_train) # Train/Fit model 

y_pred1 = model1.predict(x_test) # get y predictions
print(classification_report(y_test, y_pred1)) # output accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.71        30
#            1       0.71      0.81      0.76        31
#
#     accuracy                           0.74        61
#    macro avg       0.74      0.74      0.74        61
# weighted avg       0.74      0.74      0.74        61

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred1))
# Out:
# [[20 10]
#  [ 6 25]]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred1)
# Out:
# 0.7377049180327869

# %% [markdown]
# The achieved accuracy is 74%.

# %%
# Prediction using Random Forest Classifier

from sklearn.metrics import classification_report 
from sklearn.ensemble import RandomForestClassifier

model6 = RandomForestClassifier(random_state=1)# get instance of model
model6.fit(x_train, y_train) # Train/Fit model 

y_pred6 = model6.predict(x_test) # get y predictions
print(classification_report(y_test, y_pred6)) # output accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        30
#            1       0.76      0.90      0.82        31
#
#     accuracy                           0.80        61
#    macro avg       0.82      0.80      0.80        61
# weighted avg       0.81      0.80      0.80        61

# %%
cm = confusion_matrix(y_test, y_pred6)
print(cm)
accuracy_score(y_test, y_pred6)
# Out:
# [[21  9]
#  [ 3 28]]
# 0.8032786885245902

# %% [markdown]
# Thus, this particular achieved accuracy of 80% is a good outcome.
